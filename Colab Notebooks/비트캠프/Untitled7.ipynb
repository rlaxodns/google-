# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
print(tf.__version__) #2.16.2

#1. 데이터
x=np.array([1,2,3])
y=np.array([1,2,3])

#2. 모델 구성
model=Sequential()
model.add(Dense(1, input_dim=1))

#3. 컴파일, 훈련
model.compile(lose='mse', optimizer='adam') #컴퓨터가 이해할 수 있도록 학습
model.fit(x,y,epochs=1)

#4. 평가, 예측
result = model.predict([4])
print("4의 예측값 :", result)
# Out:
# 2.15.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-da320fdb387f> in <cell line: 16>()
#      14
#      15 #3. 컴파일, 훈련
# ---> 16 model.compile(lose='mse', optimizer='adam') #컴퓨터가 이해할 수 있도록 학습
#      17 model.fit(x,y,epochs=1)
#      18
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in _validate_compile(self, optimizer, metrics, **kwargs)
#    3893         invalid_kwargs = set(kwargs) - {"sample_weight_mode"}
#    3894         if invalid_kwargs:
# -> 3895             raise TypeError(
#    3896                 "Invalid keyword argument(s) in `compile()`: "
#    3897                 f"{(invalid_kwargs,)}. Valid keyword arguments include "
#
# TypeError: Invalid keyword argument(s) in `compile()`: ({'lose'},). Valid keyword arguments include "cloning", "experimental_run_tf_function", "distribute", "target_tensors", or "sample_weight_mode".
