# %% [markdown]
# [Sample Question] for Final Exam
#
# Topic 14 [HT procedure]
# ~ Topic 21 [Regression_Multicollinearity]
# **굵은 텍스트**
#
# 1) 다음 분석 주제 중 t-검정(t-test)로 수행 가능한 것이 아닌 것은 무엇인가?
#
# ① 선호제품과 성별과의 관련성 검정
# ② 모의류업체 대리점들의 평균매출액이 목표금액을 초과했는지 검정
# ③ 특정 지역의 일별 평균교통량이 작년과 차이가 있는지 검정
# ④ 회원들의 홈페이지 평균 방문횟수가 목표횟수를 달성했는지 검정
