# %%
df = pd.read_csv('SeoulBikeData.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0353c0f269c5> in <cell line: 1>()
# ----> 1 df = pd.read_csv('SeoulBikeData.csv')
#
# NameError: name 'pd' is not defined
