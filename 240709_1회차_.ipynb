# %% [markdown]
# <a href="https://colab.research.google.com/github/rlaxodns/google-/blob/main/240709_1%ED%9A%8C%EC%B0%A8_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)

import numpy as np

print(np.__version__)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

print(tf.__version__)

#1. 데이터
x= np.array([1,2,3])
y= np.array([1,2,3])

#2. 모델구성
model= Sequential()
model.add(Dense(1, input_dim=1))

#3. 컴파일, 훈련
model.compile(loss='mse', optimizer='adam')
model.fit(x, y, epochs=1000)

#4. 평가, 예측
result=model.predict([4])
print(result)
# Out:
# 2.15.0
# 1.25.2
# 2.15.0
# Epoch 1/1000
# 1/1 [==============================] - 1s 631ms/step - loss: 2.0566
# Epoch 2/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 2.0477
# Epoch 3/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0389
# Epoch 4/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0301
# Epoch 5/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0213
# Epoch 6/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0126
# Epoch 7/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0038
# Epoch 8/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9951
# Epoch 9/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9864
# Epoch 10/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9777
# Epoch 11/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9691
# Epoch 12/1000
# ...

# %% [markdown]
# 2회차 7/10

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

#1.데이터
x=np.array([1,2,3,4,5,6])
y=np.array([1,2,3,4,5,6])

#2. 모델을 구성
model= Sequential()
model.add(Dense(1, input_dim=1))

#3. 컴파일 훈련
model.compile(loss='mse', optimizer='adam')
model.fit(x,y,epochs=10000)

#4. 평가 및 예측 + 로스값 추가
loss=model.evaluate(x,y)
result= model.predict([7])

print(loss)
print(result)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 7503/10000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00
# Epoch 7504/10000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0000e+00
# Epoch 7505/10000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0000e+00
# Epoch 7506/10000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0000e+00
# Epoch 7507/10000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0000e+00
# Epoch 7508/10000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0000e+00
# Epoch 7509/10000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0000e+00
# Epoch 7510/10000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00
# Epoch 7511/10000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00
# Epoch 7512/10000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00
# Epoch 7513/10000
# ...
